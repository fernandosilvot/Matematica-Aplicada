# %% [markdown]
# # Ponderacion de Matrices

# %% [markdown]
# ### Importamos la libreria "Numpy"

# %%
import numpy as np

# %% [markdown]
# ### Empezamos con los Ejercicios

# %% [markdown]
# ##### Ejercicio 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
B = np.array([[-4,-2],[7,1]])
B3 = -3*B
print(f"la matriz -3B 1.1 es: {B3[0,0]}")
# Out:
# la matriz -3B 1.1 es: 12

# %% [markdown]
# ##### Ejercicio 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
C = np.array([[-42],[27],[-3]])
C3 = (1/3)*C
print(f"la matriz (1/3)C 1.1 es: {C3[0,0]}")
# Out:
# la matriz (1/3)C 1.1 es: -14.0

# %% [markdown]
# ##### Ejercicio 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
D = np.array([[0],[-1],[-2]])
D2 = -2*D
print(f"la matriz -2D 1.1 es: {D2[0,0]}")
# Out:
# la matriz -2D 1.1 es: 0

# %% [markdown]
# ##### Ejercicio 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
E = np.array([[-2,4,3],[2,-2,-2]])
E5 = -5*E
print(f"la matriz -5E 1.1 es: {E5[0,0]}")
# Out:
# la matriz -5E 1.1 es: 10

# %% [markdown]
# ##### Ejercicio  5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
F = np.array([[-2,-2],[-1,0]])
F2 = 2*F
print(f"la matriz 2F 1.1 es: {F2[0,0]}")
# Out:
# la matriz 2F 1.1 es: -4

# %% [markdown]
# ##### Ejercicio 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
G = np.array([[0,3],[3,-1],[2,-2]])
G6 = -6*G
print(f"la matriz -6G 1.1 es: {G6[0,0]}")
# Out:
# la matriz -6G 1.1 es: 0

# %% [markdown]
# ##### Ejercicio 7

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
C = np.array([[120,70],[150,110],[80,160]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
E = 0.8*C
print(f"la matriz E es: \n{E}\n")
# Out:
# la matriz E es:
# [[ 96.  56.]
#  [120.  88.]
#  [ 64. 128.]]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
T = C + E
print(f"la matriz T es: \n{T}\n")
# Out:
# la matriz T es:
# [[216. 126.]
#  [270. 198.]
#  [144. 288.]]

# %% [markdown]
# ##### Ejercicio 8

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
V = np.array([[30,34,20],[45,20,16],[14,26,25]])

T = np.array([[35,30,26],[52,25,18],[23,24,32]])

V = 0.7 * V

T = 0.9 * T

B = V + T

print(f"La matriz b1,3 = {B[0,2]:.2f}")
# Out:
# La matriz b1,3 = 37.40

# %% [markdown]
# ##### Ejercicio 9

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
C = np.array([[120,70],[150,110],[80,160]])

F = 1.15 * C

print(f"La matriz F es: \n{F}\n")
# Out:
# La matriz F es:
# [[138.   80.5]
#  [172.5 126.5]
#  [ 92.  184. ]]

# %% [markdown]
# ##### Ejercicio 10

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = np.array([[65,64,46],[97,45,34],[37,50,57]])

B = 0.9 * A

print(f"La matriz B es: \n{B}\n")
# Out:
# La matriz B es:
# [[58.5 57.6 41.4]
#  [87.3 40.5 30.6]
#  [33.3 45.  51.3]]
