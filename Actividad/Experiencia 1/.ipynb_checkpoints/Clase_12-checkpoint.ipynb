# %% [markdown]
# ## Importamos numpy

# %%
import numpy as np

# %% [markdown]
# # Matricez transpuesta

# %% [markdown]
# ## Empezamos con los ejercicios

# %% [markdown]
# ##### Ejercicio 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
primera = np.array([[7,-3],[4,1],[-2,0],[8,5]])
primeraT = primera.T
print(f"la matriz primeraT es: \n{primeraT}\n")
# Out:
# la matriz primeraT es:
# [[ 7  4 -2  8]
#  [-3  1  0  5]]

# %% [markdown]
# ##### Ejercicio 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
segunda = np.array([[2,8],[0,1],[-5,-4]])
segundaT = segunda.T
print(f"la matriz segundaT es: \n{segundaT}\n")
# Out:
# la matriz segundaT es:
# [[ 2  0 -5]
#  [ 8  1 -4]]

# %% [markdown]
# # Multiplicacion de matrices

# %% [markdown]
# # Matricez transpuesta

# %% [markdown]
# ##### Ejercicio 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
G = np.array([[55,39,68],[33,59,64],[72,63,62]])
H = np.array([[550,500],[650,700],[450,400]])
GH = G.dot(H)
print(f"la matriz GH es: \n{GH}\n")
# Out:
# la matriz GH es:
# [[ 86200  82000]
#  [ 85300  83400]
#  [108450 104900]]

# %% [markdown]
# ##### Ejercicio 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
M = np.array([[2,8,3],[5,4,1]])
N = np.array([[4,1],[6,3],[2,4]])
P = M.dot(N)
print(f"la matriz P es: \n{P}\n")
# Out:
# la matriz P es:
# [[62 38]
#  [46 21]]

# %% [markdown]
# ##### Ejercicio 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
M = np.array([[9,14],[4,5]])
Q = np.array([[200,240,220],[175,210,215]])
I = M.dot(Q)
print(f"la matriz I es: \n{I}\n")
print(f"la matriz H no se puede calcular\n")
# Out:
# la matriz I es:
# [[4250 5100 4990]
#  [1675 2010 1955]]
#
# la matriz H no se puede calcular

# %% [markdown]
# ##### Ejercicio 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = np.array([[2,0,1],[3,0,0],[5,1,1]])
B = np.array([[1,0,1],[1,2,1],[1,1,0]])
AB = A.dot(B)
print(f"la matriz AB es: \n{AB}\n")
# Out:
# la matriz AB es:
# [[3 1 2]
#  [3 0 3]
#  [7 3 6]]

# %% [markdown]
# ##### Ejercicio 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = np.array([[4,3],[7,6]])
B = np.array([[1,0],[3,6],[5,8]])
#AB = A.dot(B)
print(f"la matriz AB no se puede calcular\n")

# 2. E*H

E = np.array([[2,3],[5,1]])
H = np.array([[51,10],[48,21]])
EH = E.dot(H)
print(f"la matriz EH es: \n{EH}\n")

# 3. J*G

J = np.array([[12,10,21],[35,14,12],[9,4,2]])
G = np.array([[-3,2,6],[9,0,12],[9,4,2]])
JG = J.dot(G)
print(f"la matriz JG es: \n{JG}\n")

# 4. B*C

B = np.array([[1,0],[3,6],[5,8]])
C = np.array([[5,10,8],[7,3,4],[12,6,9]])
#BC = B.dot(C)
print(f"la matriz BC no se puede calcular\n")
# Out:
# la matriz AB no se puede calcular
#
# la matriz EH es:
# [[246  83]
#  [303  71]]
#
# la matriz JG es:
# [[243 108 234]
#  [129 118 402]
#  [ 27  26 106]]
#
# la matriz BC no se puede calcular
